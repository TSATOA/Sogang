# %%
# import packages
import matplotlib.pyplot as plt
from tqdm import tqdm # optional
import random

# 100번 수행
num_iterations = 10000
random_integers = []

## write answer
for i in range(num_iterations):
  random_integers.append(random.randint(0,100))


fig = plt.figure()
plt.hist(random_integers)
plt.title(f"Check Uniform Distribution of {num_iterations} iterations")
plt.xlabel("Numbers")
plt.ylabel("N of each number")
plt.xlim([0, 99])
plt.show()

# %%
def lcg(seed, loop, m=2**32, a=214013, c=2531011):
    for i in range(loop):
        # write answer
        seed = (a*seed+c) %m
        yield seed

num_iterations = 10000
random_generator = lcg(seed=13, loop=num_iterations, m=2**32)
random_integers = []

## write answer
for i in range(num_iterations):
  random_integers.append(next(random_generator))


fig = plt.figure()
plt.hist(random_integers)
plt.title(f"Check Uniform Distribution of {num_iterations} iterations")
plt.xlabel("Numbers")
plt.ylabel("N of each number")
plt.xlim([0, 2**32])
plt.show()

# %%
# 출력시 컬러 지원 가능 모듈 설치
# !pip install termcolor
from termcolor import colored
# !pip install colorama
from colorama import init, Fore, Back, Style

def roll_dice():
    ## write answer
    dice_tries.append([random.randint(1,6),random.randint(1,6)])
    pass


dice_tries = []
num_iterations = 100
hits = 0
for _ in range(num_iterations):
    ## write answer
    roll_dice()
    pass

print("="*100)
print(colored("* 두 주사위의 합이 8인 경우에는 cyan 색의 음영이 들어가 있음 *", 'red'))

for i in range(num_iterations):
  ## write answer
  if((i+1)%5==0):
    if(dice_tries[i][0]+dice_tries[i][1]==8):
        hits +=1
        print(colored("try %2d : %d %d " %(i,dice_tries[i][0],dice_tries[i][1]), 'yellow','on_cyan'))
    else:
        print("try %2d : %d %d " %(i,dice_tries[i][0],dice_tries[i][1]))
  else:
    if(dice_tries[i][0]+dice_tries[i][1]==8):
        hits +=1
        print(colored("try %2d : %d %d " %(i,dice_tries[i][0],dice_tries[i][1]), 'yellow', 'on_cyan'),end=' ')
    else:
        print("try %2d : %d %d " %(i,dice_tries[i][0],dice_tries[i][1]),end=' ')
      

  pass


print(colored("\n실제 값 : 0.138889", "red"))
print(colored(f"계산된 값 : {round(hits / num_iterations,6)}", "red"))
print(colored(f"오차율 : {abs(hits / num_iterations - 5/36) / (5/36) * 100} %", "red"))
print("="*100)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.5)
# ====================================================================================================
# * 두 주사위의 합이 8인 경우에는 cyan 색의 음영이 들어가 있음 *
# try  0 : 2 6  try  1 : 4 2  try  2 : 1 6  try  3 : 4 5  try  4 : 5 4
# try  5 : 6 2  try  6 : 2 1  try  7 : 5 4  try  8 : 3 4  try  9 : 6 6
# try 10 : 4 2  try 11 : 2 4  try 12 : 3 1  try 13 : 1 2  try 14 : 4 4
# try 15 : 4 5  try 16 : 2 4  try 17 : 6 1  try 18 : 4 4  try 19 : 4 6
# try 20 : 6 3  try 21 : 4 2  try 22 : 1 3  try 23 : 5 4  try 24 : 2 4
# try 25 : 1 6  try 26 : 1 5  try 27 : 1 5  try 28 : 6 1  try 29 : 5 3
# try 30 : 4 2  try 31 : 4 6  try 32 : 4 6  try 33 : 2 2  try 34 : 4 2
# try 35 : 2 3  try 36 : 1 5  try 37 : 5 1  try 38 : 4 3  try 39 : 1 5
# try 40 : 3 4  try 41 : 6 5  try 42 : 2 3  try 43 : 6 4  try 44 : 4 6
# try 45 : 3 6  try 46 : 6 4  try 47 : 5 6  try 48 : 1 5  try 49 : 2 2
# try 50 : 4 4  try 51 : 2 6  try 52 : 5 5  try 53 : 4 1  try 54 : 5 2
# try 55 : 3 4  try 56 : 4 4  try 57 : 1 3  try 58 : 4 1  try 59 : 5 5
# try 60 : 3 5  try 61 : 1 3  try 62 : 4 1  try 63 : 1 6  try 64 : 3 6
# try 65 : 2 5  try 66 : 1 6  try 67 : 4 6  try 68 : 3 3  try 69 : 1 6
# try 70 : 4 6  try 71 : 5 3  try 72 : 5 2  try 73 : 5 5  try 74 : 6 3
# try 75 : 2 3  try 76 : 1 3  try 77 : 6 5  try 78 : 1 1  try 79 : 3 5
# try 80 : 2 4  try 81 : 5 2  try 82 : 1 3  try 83 : 3 3  try 84 : 6 5
# try 85 : 2 3  try 86 : 1 1  try 87 : 2 5  try 88 : 6 3  try 89 : 2 4
# try 90 : 1 4  try 91 : 6 1  try 92 : 3 4  try 93 : 3 5  try 94 : 6 5
# try 95 : 5 5  try 96 : 2 2  try 97 : 4 6  try 98 : 3 5  try 99 : 4 5
#
# 실제 값 : 0.138889
# 계산된 값 : 0.13
# 오차율 : 6.400000000000001 %
# ====================================================================================================

# %%
import matplotlib.pyplot as plt
def roll_dice():
    ## write answer
    throw.clear()
    money=1000
    win=0
    mon.clear()
    for i in range(max_num_rolls):
      throw.append([random.randint(1,6),random.randint(1,6)])
      if(throw[i][0]==throw[i][1]):
        win+=1
        money +=4
      else:
        money -=1
      mon.append(money)
    win_probability.append(win/max_num_rolls)
    end_balance.append(money)
    plt.plot(mon)
    pass

# Inputs
num_simulations = 10000
max_num_rolls = 1000
bet = 1

mon = []
throw = []
win_probability = []
end_balance = []

plt.figure(figsize=(12,6))



for i in range(num_simulations):
    ## write answer
    roll_dice()
    continue


plt.title("Monte Carlo Dice Game [" + str(num_simulations) + " players simulations]")
plt.xlabel("Roll Number")
plt.ylabel("Balance [$]")
plt.xlim([0, max_num_rolls])


overall_win_probability = sum(win_probability)/num_simulations
overall_end_balance = sum(end_balance)/num_simulations

print(f"10000명 플레이어의 {max_num_rolls}번 수행 횟수 시 평균 승률" + "  :  " + colored(f"{overall_win_probability:.2f}","red"))
print(f"10000명 플레이어의 {max_num_rolls}번 수행 횟수 시 평균 잔액 "  + f" : {colored('$','red')}" + colored(f"{overall_end_balance:.2f}","red"))
# Out:
# 10000명 플레이어의 1000번 수행 횟수 시 평균 승률  :  0.17
# 10000명 플레이어의 1000번 수행 횟수 시 평균 잔액  : $833.47

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

MAX_POINTS = 50000
x_coords = []
y_coords = []
in_markers_x = []
in_markers_y = []


## write answer
for i in range(MAX_POINTS):
  a=random.uniform(-1,1)
  b=random.uniform(-1,1)
  if(a*a+b*b<1):
    in_markers_x.append(a)
    in_markers_y.append(b)
  else:
    x_coords.append(a)
    y_coords.append(b)

pi = len(in_markers_x)/MAX_POINTS*4

plt.rcParams['figure.figsize'] = (24, 12)
font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}
box1 = {'boxstyle': 'round',
        'ec': (1.0, 0.5, 0.5),
        'fc': (1.0, 0.8, 0.8)}

fig, ax = plt.subplots(1)
# write code
# ax.scatter 이용
ax.scatter(x_coords,y_coords,s=1,c='blue')
ax.scatter(in_markers_x,in_markers_y,s=1,c='red')


ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params('both', length=0)    
ax.set_aspect('equal')
ax.text(-1.8,1.4, f"Number of iteration : {MAX_POINTS}\nEstimated pi : {pi:.6f}\nReal pi : 3.141593\nError rate : {abs(pi-3.141593)/3.141593*100:.2f}%", fontdict=font1, bbox=box1)
ax.patch.set_facecolor('#069af3') ## axes 배경색
ax.patch.set_alpha(0.5) ## axes 투명도
ax.add_patch(
   patches.Rectangle(
      (-1, -1),                   # (x, y)
      2, 2,                     # width, height
      edgecolor = 'black',
      facecolor = 'lightgray',
      fill=False,
   ))
plt.xlim([-2,2])
plt.ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# 시뮬레이션 횟수
N_ROUNDS = 10000
results = []
for rnd in range(N_ROUNDS):
    ## write answer
    if(random.randint(0,1)==1):
      sales = np.random.triangular(1,3,9)*(np.random.triangular(0.25,0.5,0.75)+1)
    else:
      sales = np.random.triangular(1,3,9)

    results.append(sales)

# 모든 시나리오에서 나온 신작 판매량의 평균 
average_sales = np.mean(results)

binned_results = pd.cut(results, bins=[0, 6, 20], labels=[
    "Probability : less than or equal to 600 million won",
    "Probability : greater than 600 million won"])


# 결과물 시각화
sns.barplot(x=binned_results.value_counts().index,
            y=binned_results.value_counts().values)
## write answer
##
##
##
##
##
##
##

C1 , C2 = binned_results.value_counts()
P1 = round(C1*100/N_ROUNDS,1)
P2 = round(C2*100/N_ROUNDS,1)

print("6억원 이하의 매출을 얻을 확률 :", colored(f"{P1}","red") )
print("6억원 초과의 매출을 얻을 확률 :", colored(f"{P2}","blue"))
# Out:
# 6억원 이하의 매출을 얻을 확률 : 65.0
# 6억원 초과의 매출을 얻을 확률 : 35.0

# %%
from pickle import NONE
import numpy as np
import seaborn as sns
from termcolor import colored

np.random.seed(1)
subscription_data = {"Month": range(1, 60), 
                     "Growth": np.random.normal(0, 0.05, 60)}

N_ROUNDS = 10000
results = []

historical_data = subscription_data["Growth"]

for rnd in range(N_ROUNDS):
    ## write answer
    money=0
    man=2000
    for i in range(12):
      man = man*(1+random.choice(historical_data))
      money+= man*50000
    results.append(money)
    pass

print("하위 1%의 수익 : ", colored(f"{sorted(results)[100] / 1e8:.4f} 억","red"))


## write answer
##
lower_revenue = sorted(results)[100]
print(f"매년 준비해야할 금액 : ",  colored(f"{(12*9.5*1e7 - lower_revenue)/1e8:.4f} 억","red"))


ax = sns.distplot(results, kde=False)
ax.set_xlabel("Average revenue across simulated 12 months")
ax.set_ylabel("# of simulations")
plt.title(f"""
Average annual revenue across simulations: 
{round(np.mean(results)/1e8, 2)}
""")
plt.show()
# Out:
# 하위 1%의 수익 :  9.4718 억
# 매년 준비해야할 금액 :  1.9282 억
